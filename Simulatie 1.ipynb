# %%
# !pip install simpy
# !pip install numpy
# Out:
# Requirement already satisfied: simpy in c:\users\lennard\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.1.1)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\Lennard\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting numpy
#   Downloading numpy-2.2.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 217.9 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 281.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 324.4 kB/s eta 0:00:00
# Downloading numpy-2.2.1-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.9 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/12.9 MB 4.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/12.9 MB 5.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.9/12.9 MB 5.4 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/12.9 MB 5.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.5/12.9 MB 5.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.7/12.9 MB 5.5 MB/s eta 0:00:03
#    ------ --------------------------------- 2.0/12.9 MB 5.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/12.9 MB 5.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.6/12.9 MB 5.7 MB/s eta 0:00:02
#    -------- ------------------------------- 2.8/12.9 MB 5.5 MB/s eta 0:00:02
#    --------- ------------------------------ 3.2/12.9 MB 5.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.5/12.9 MB 5.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.8/12.9 MB 5.9 MB/s eta 0:00:02
#    ------------ --------------------------- 4.0/12.9 MB 5.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.3/12.9 MB 5.9 MB/s eta 0:00:02
#    -------------- ------------------------- 4.6/12.9 MB 5.9 MB/s eta 0:00:02
#    --------------- ------------------------ 4.9/12.9 MB 5.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.3/12.9 MB 6.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.9 MB 6.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.8/12.9 MB 5.8 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/12.9 MB 5.9 MB/s eta 0:00:02
#    ------------------- -------------------- 6.2/12.9 MB 5.9 MB/s eta 0:00:02
#    -------------------- ------------------- 6.5/12.9 MB 5.8 MB/s eta 0:00:02
#    -------------------- ------------------- 6.7/12.9 MB 5.8 MB/s eta 0:00:02
#    --------------------- ------------------ 7.0/12.9 MB 5.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.2/12.9 MB 5.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.5/12.9 MB 5.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.7/12.9 MB 5.7 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.9 MB 5.7 MB/s eta 0:00:01
#    ------------------------- -------------- 8.2/12.9 MB 5.7 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.9 MB 5.7 MB/s eta 0:00:01
#    -------------------------- ------------- 8.7/12.9 MB 5.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/12.9 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.9 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.9 MB 5.6 MB/s eta 0:00:01
#    ------------------------------ --------- 9.8/12.9 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.9 MB 5.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.9 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 10.8/12.9 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.2/12.9 MB 6.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.6/12.9 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 6.0 MB/s eta 0:00:01
#    -------------------------------------- - 12.4/12.9 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  12.7/12.9 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  12.9/12.9 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  12.9/12.9 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 5.7 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.1
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\Lennard\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import simpy
import numpy as np

# Define the parameters
class IntersectionSimulation:
    def __init__(self, env, arrival_distributions, crossing_times, row_times):
        self.env = env
        self.arrival_distributions = arrival_distributions  # Vehicle entrance distributions
        self.crossing_times = crossing_times  # Crossing time distribution parameters
        self.row_times = row_times  # Time to move from row i to row i-1
        self.queues = {street: [] for street in arrival_distributions}
        self.light_state = {street: False for street in arrival_distributions}
        self.results = {street: [] for street in arrival_distributions}
        self.vehicle_count = 0  # Counter to number vehicles

        env.process(self.traffic_light_cycle())
        for street in arrival_distributions:
            env.process(self.vehicle_arrival(street))

    def traffic_light_cycle(self):
        """Controls the traffic light system."""
        cycle_order = [('Bakeri1', 30), ('Bakeri2', 25), ('Besat1', 30), ('Besat2', 30)]
        while True:
            for street, green_time in cycle_order:
                self.light_state[street] = True
                if self.env.now < 500:
                    print(f"Time {self.env.now:.2f}: Light turned GREEN for {street}")
                yield self.env.timeout(green_time)
                self.light_state[street] = False

    def vehicle_arrival(self, street):
        """Generates vehicles arriving at the intersection."""
        while True:
            inter_arrival_time = max(0.1, self.arrival_distributions[street]())  # Ensure positive delay
            yield self.env.timeout(inter_arrival_time)
            self.vehicle_count += 1
            vehicle_id = self.vehicle_count
            self.env.process(self.vehicle_cross(street, vehicle_id))

    def vehicle_cross(self, street, vehicle_id):
        """Simulates a vehicle's journey through the intersection."""
        arrival_time = self.env.now
        queue_length = len(self.queues[street])
        wait_time = queue_length * self.row_times[street]

        self.queues[street].append((vehicle_id, arrival_time))

        yield self.env.timeout(wait_time)
        while not self.light_state[street]:
            yield self.env.timeout(1)  # Wait for green light

        crossing_time = max(0.1, self.crossing_times[street]())  # Ensure positive crossing time
        yield self.env.timeout(crossing_time)

        _, start_time = self.queues[street].pop(0)
        cycle_time = self.env.now - start_time
        self.results[street].append(cycle_time)

        if self.env.now < 500:  # Print only for the first 200 time units
            print(f"Time {self.env.now:.2f}: Vehicle {vehicle_id} from {street} crossed after {cycle_time:.2f} seconds")

    def get_results(self):
        return {street: np.mean(times) if times else 0 for street, times in self.results.items()}

# Define scenario parameters
arrival_distributions = {
    'Bakeri1': lambda: max(0.1, -0.5 + 22 * np.random.beta(0.971, 2.04)),
    'Bakeri2': lambda: max(0.1, -0.5 + 41 * np.random.beta(0.968, 3.44)),
    'Besat1': lambda: max(0.1, -0.5 + 23 * np.random.beta(0.634, 1.61)),
    'Besat2': lambda: max(0.1, -0.5 + 24 * np.random.beta(0.963, 1.99))
}

crossing_times = {
    'Bakeri1': lambda: max(0.1, np.random.poisson(8.21)),
    'Bakeri2': lambda: max(0.1, np.random.normal(5.66, 2.08)),
    'Besat1': lambda: max(0.1, 2.5 + min(15, np.random.lognormal(7.65, 6.42))),
    'Besat2': lambda: max(0.1, 2.5 + np.random.gamma(2.82, 3))
}

row_times = {
    'Bakeri1': 2.675,
    'Bakeri2': 2.4666,
    'Besat1': 2.6818,
    'Besat2': 2.3243
}

# Run the simulation
env = simpy.Environment()
sim = IntersectionSimulation(env, arrival_distributions, crossing_times, row_times)
env.run(until=10000)  # Run simulation for 10,000 time units

# Print results
results = sim.get_results()
print("Average vehicle cycle time per street:")
for street, avg_time in results.items():
    print(f"{street}: {avg_time:.2f} seconds")
# Out:
# Time 0.00: Light turned GREEN for Bakeri1
# Time 15.43: Vehicle 2 from Bakeri1 crossed after 7.00 seconds
# Time 21.39: Vehicle 3 from Bakeri1 crossed after 12.67 seconds
# Time 27.30: Vehicle 6 from Bakeri1 crossed after 15.35 seconds
# Time 30.00: Light turned GREEN for Bakeri2
# Time 35.45: Vehicle 4 from Bakeri2 crossed after 25.68 seconds
# Time 35.73: Vehicle 11 from Bakeri2 crossed after 16.87 seconds
# Time 38.07: Vehicle 12 from Bakeri1 crossed after 14.68 seconds
# Time 38.85: Vehicle 13 from Bakeri1 crossed after 15.35 seconds
# Time 45.59: Vehicle 20 from Bakeri2 crossed after 5.23 seconds
# Time 50.55: Vehicle 26 from Bakeri2 crossed after 0.62 seconds
# Time 55.00: Light turned GREEN for Besat1
# Time 60.09: Vehicle 8 from Besat1 crossed after 59.99 seconds
# Time 72.54: Vehicle 22 from Besat1 crossed after 59.09 seconds
# Time 72.60: Vehicle 1 from Besat1 crossed after 56.47 seconds
# Time 72.61: Vehicle 17 from Besat1 crossed after 35.55 seconds
# Time 72.99: Vehicle 10 from Besat1 crossed after 30.68 seconds
# Time 81.79: Vehicle 28 from Besat1 crossed after 30.91 seconds
# Time 85.00: Light turned GREEN for Besat2
# Time 86.41: Vehicle 29 from Besat1 crossed after 33.59 seconds
# Time 89.43: Vehicle 39 from Besat1 crossed after 27.22 seconds
# Time 91.65: Vehicle 38 from Besat2 crossed after 81.71 seconds
# Time 94.57: Vehicle 7 from Besat2 crossed after 82.28 seconds
# Time 95.79: Vehicle 33 from Besat1 crossed after 30.14 seconds
# Time 97.44: Vehicle 37 from Besat2 crossed after 81.48 seconds
# Time 98.63: Vehicle 5 from Besat2 crossed after 69.82 seconds
# Time 98.85: Vehicle 15 from Besat2 crossed after 60.83 seconds
# Time 99.22: Vehicle 30 from Besat2 crossed after 56.63 seconds
# Time 100.75: Vehicle 23 from Besat2 crossed after 43.00 seconds
# Time 101.93: Vehicle 34 from Besat1 crossed after 28.27 seconds
# Time 102.99: Vehicle 9 from Besat2 crossed after 35.58 seconds
# Time 103.44: Vehicle 18 from Besat2 crossed after 34.11 seconds
# Time 107.58: Vehicle 41 from Besat2 crossed after 31.00 seconds
# Time 115.00: Light turned GREEN for Bakeri1
# Time 117.54: Vehicle 35 from Bakeri1 crossed after 88.82 seconds
# Time 119.46: Vehicle 43 from Bakeri1 crossed after 84.74 seconds
# Time 120.74: Vehicle 16 from Bakeri1 crossed after 81.39 seconds
# Time 121.70: Vehicle 19 from Bakeri1 crossed after 81.23 seconds
# Time 122.23: Vehicle 44 from Bakeri1 crossed after 76.97 seconds
# Time 122.96: Vehicle 24 from Bakeri1 crossed after 75.57 seconds
# Time 122.98: Vehicle 27 from Bakeri1 crossed after 73.05 seconds
# Time 123.49: Vehicle 21 from Bakeri1 crossed after 57.68 seconds
# Time 125.29: Vehicle 46 from Bakeri1 crossed after 59.33 seconds
# Time 128.07: Vehicle 14 from Bakeri1 crossed after 46.69 seconds
# Time 128.36: Vehicle 36 from Bakeri1 crossed after 46.88 seconds
# Time 128.77: Vehicle 25 from Bakeri1 crossed after 41.90 seconds
# Time 136.88: Vehicle 55 from Bakeri1 crossed after 37.10 seconds
# Time 145.00: Light turned GREEN for Bakeri2
# Time 148.93: Vehicle 69 from Bakeri1 crossed after 31.05 seconds
# Time 148.99: Vehicle 58 from Bakeri2 crossed after 89.05 seconds
# Time 149.51: Vehicle 68 from Bakeri1 crossed after 28.51 seconds
# Time 149.61: Vehicle 32 from Bakeri2 crossed after 89.02 seconds
# Time 150.30: Vehicle 63 from Bakeri2 crossed after 70.44 seconds
# Time 151.16: Vehicle 42 from Bakeri2 crossed after 54.21 seconds
# Time 152.28: Vehicle 54 from Bakeri2 crossed after 53.50 seconds
# Time 152.47: Vehicle 51 from Bakeri2 crossed after 41.38 seconds
# Time 152.50: Vehicle 61 from Bakeri2 crossed after 40.80 seconds
# Time 155.93: Vehicle 31 from Bakeri2 crossed after 41.35 seconds
# Time 161.63: Vehicle 71 from Bakeri2 crossed after 28.70 seconds
# Time 165.93: Vehicle 73 from Bakeri2 crossed after 27.60 seconds
# Time 167.86: Vehicle 75 from Bakeri2 crossed after 29.05 seconds
# Time 170.00: Light turned GREEN for Besat1
# Time 171.80: Vehicle 76 from Bakeri2 crossed after 30.73 seconds
# Time 172.63: Vehicle 66 from Besat1 crossed after 98.49 seconds
# Time 172.97: Vehicle 70 from Besat1 crossed after 90.98 seconds
# Time 173.55: Vehicle 85 from Bakeri2 crossed after 26.89 seconds
# Time 180.08: Vehicle 45 from Besat1 crossed after 93.11 seconds
# Time 187.47: Vehicle 48 from Besat1 crossed after 94.97 seconds
# Time 187.76: Vehicle 67 from Besat1 crossed after 89.17 seconds
# Time 187.88: Vehicle 47 from Besat1 crossed after 89.19 seconds
# Time 187.89: Vehicle 62 from Besat1 crossed after 87.98 seconds
# Time 188.05: Vehicle 40 from Besat1 crossed after 83.85 seconds
# Time 188.18: Vehicle 74 from Besat1 crossed after 76.24 seconds
# Time 188.18: Vehicle 56 from Besat1 crossed after 66.28 seconds
# Time 188.28: Vehicle 53 from Besat1 crossed after 65.84 seconds
# Time 188.47: Vehicle 57 from Besat1 crossed after 57.53 seconds
# Time 188.50: Vehicle 52 from Besat1 crossed after 50.01 seconds
# Time 200.00: Light turned GREEN for Besat2
# Time 200.08: Vehicle 80 from Besat1 crossed after 52.36 seconds
# Time 202.86: Vehicle 81 from Besat1 crossed after 55.05 seconds
# Time 204.86: Vehicle 59 from Besat2 crossed after 110.36 seconds
# Time 205.88: Vehicle 49 from Besat2 crossed after 109.87 seconds
# Time 206.78: Vehicle 82 from Besat1 crossed after 57.73 seconds
# Time 207.78: Vehicle 88 from Besat2 crossed after 96.56 seconds
# Time 208.00: Vehicle 97 from Besat2 crossed after 96.68 seconds
# Time 209.07: Vehicle 50 from Besat2 crossed after 75.63 seconds
# Time 209.09: Vehicle 87 from Besat2 crossed after 65.10 seconds
# Time 211.07: Vehicle 77 from Besat2 crossed after 61.45 seconds
# Time 211.52: Vehicle 83 from Besat2 crossed after 52.27 seconds
# Time 213.13: Vehicle 60 from Besat2 crossed after 53.07 seconds
# Time 213.98: Vehicle 72 from Besat2 crossed after 43.69 seconds
# Time 216.75: Vehicle 103 from Besat2 crossed after 40.81 seconds
# Time 216.79: Vehicle 95 from Besat2 crossed after 36.85 seconds
# Time 218.58: Vehicle 102 from Besat2 crossed after 38.54 seconds
# Time 230.00: Light turned GREEN for Bakeri1
# Time 232.40: Vehicle 84 from Bakeri1 crossed after 104.94 seconds
# Time 234.87: Vehicle 114 from Besat2 crossed after 36.21 seconds
# Time 235.84: Vehicle 123 from Besat2 crossed after 31.38 seconds
# Time 236.98: Vehicle 64 from Bakeri1 crossed after 108.43 seconds
# Time 237.91: Vehicle 89 from Bakeri1 crossed after 91.22 seconds
# Time 238.49: Vehicle 91 from Bakeri1 crossed after 84.11 seconds
# Time 239.83: Vehicle 113 from Bakeri1 crossed after 78.62 seconds
# Time 240.06: Vehicle 112 from Bakeri1 crossed after 76.94 seconds
# Time 240.39: Vehicle 79 from Bakeri1 crossed after 61.35 seconds
# Time 240.42: Vehicle 65 from Bakeri1 crossed after 57.57 seconds
# Time 241.09: Vehicle 100 from Bakeri1 crossed after 44.43 seconds
# Time 241.74: Vehicle 117 from Bakeri1 crossed after 44.99 seconds
# Time 242.59: Vehicle 118 from Bakeri1 crossed after 37.60 seconds
# Time 244.58: Vehicle 104 from Bakeri1 crossed after 36.41 seconds
# Time 260.00: Light turned GREEN for Bakeri2
# Time 261.11: Vehicle 109 from Bakeri2 crossed after 104.95 seconds
# Time 263.13: Vehicle 139 from Bakeri1 crossed after 35.39 seconds
# Time 263.22: Vehicle 106 from Bakeri2 crossed after 100.32 seconds
# Time 263.84: Vehicle 130 from Bakeri1 crossed after 34.47 seconds
# Time 265.87: Vehicle 99 from Bakeri2 crossed after 102.07 seconds
# Time 266.15: Vehicle 92 from Bakeri2 crossed after 99.50 seconds
# Time 266.65: Vehicle 90 from Bakeri2 crossed after 92.57 seconds
# Time 267.41: Vehicle 94 from Bakeri2 crossed after 91.34 seconds
# Time 267.56: Vehicle 96 from Bakeri2 crossed after 91.39 seconds
# Time 267.95: Vehicle 126 from Bakeri2 crossed after 83.75 seconds
# Time 268.32: Vehicle 107 from Bakeri2 crossed after 83.39 seconds
# Time 268.50: Vehicle 78 from Bakeri2 crossed after 75.14 seconds
# Time 269.19: Vehicle 98 from Bakeri2 crossed after 43.94 seconds
# Time 277.48: Vehicle 141 from Bakeri2 crossed after 31.09 seconds
# Time 285.00: Light turned GREEN for Besat1
# Time 287.30: Vehicle 156 from Bakeri2 crossed after 28.76 seconds
# Time 287.39: Vehicle 159 from Bakeri2 crossed after 12.66 seconds
# Time 287.62: Vehicle 120 from Besat1 crossed after 129.87 seconds
# Time 287.69: Vehicle 122 from Besat1 crossed after 123.57 seconds
# Time 288.11: Vehicle 128 from Besat1 crossed after 108.31 seconds
# Time 291.26: Vehicle 86 from Besat1 crossed after 107.11 seconds
# Time 298.21: Vehicle 121 from Besat1 crossed after 112.11 seconds
# Time 302.50: Vehicle 119 from Besat1 crossed after 109.09 seconds
# Time 302.56: Vehicle 105 from Besat1 crossed after 108.90 seconds
# Time 302.86: Vehicle 124 from Besat1 crossed after 99.83 seconds
# Time 302.92: Vehicle 136 from Besat1 crossed after 91.37 seconds
# Time 302.98: Vehicle 125 from Besat1 crossed after 91.00 seconds
# Time 302.98: Vehicle 115 from Besat1 crossed after 90.00 seconds
# Time 303.20: Vehicle 108 from Besat1 crossed after 85.55 seconds
# Time 303.21: Vehicle 101 from Besat1 crossed after 81.03 seconds
# Time 303.21: Vehicle 93 from Besat1 crossed after 78.59 seconds
# Time 303.30: Vehicle 111 from Besat1 crossed after 77.02 seconds
# Time 303.32: Vehicle 127 from Besat1 crossed after 76.95 seconds
# Time 303.36: Vehicle 110 from Besat1 crossed after 65.85 seconds
# Time 310.74: Vehicle 142 from Besat1 crossed after 63.09 seconds
# Time 315.00: Light turned GREEN for Besat2
# Time 319.28: Vehicle 137 from Besat2 crossed after 98.82 seconds
# Time 320.17: Vehicle 140 from Besat2 crossed after 92.68 seconds
# Time 321.89: Vehicle 154 from Besat2 crossed after 91.26 seconds
# Time 322.47: Vehicle 116 from Besat2 crossed after 90.59 seconds
# Time 322.57: Vehicle 146 from Besat2 crossed after 86.42 seconds
# Time 322.98: Vehicle 155 from Besat2 crossed after 85.08 seconds
# Time 323.09: Vehicle 138 from Besat2 crossed after 83.51 seconds
# Time 323.79: Vehicle 135 from Besat2 crossed after 79.31 seconds
# Time 323.85: Vehicle 147 from Besat1 crossed after 65.77 seconds
# Time 324.30: Vehicle 132 from Besat2 crossed after 70.75 seconds
# Time 326.51: Vehicle 153 from Besat2 crossed after 71.55 seconds
# Time 326.77: Vehicle 143 from Besat2 crossed after 55.10 seconds
# Time 328.07: Vehicle 134 from Besat2 crossed after 54.63 seconds
# Time 328.31: Vehicle 129 from Besat2 crossed after 54.77 seconds
# Time 328.59: Vehicle 166 from Besat2 crossed after 36.44 seconds
# Time 340.46: Vehicle 174 from Besat2 crossed after 38.75 seconds
# Time 345.00: Light turned GREEN for Bakeri1
# Time 350.09: Vehicle 133 from Bakeri1 crossed after 118.45 seconds
# Time 350.16: Vehicle 157 from Bakeri1 crossed after 108.41 seconds
# Time 351.17: Vehicle 165 from Bakeri1 crossed after 96.93 seconds
# Time 351.37: Vehicle 175 from Bakeri1 crossed after 97.03 seconds
# Time 351.39: Vehicle 162 from Bakeri1 crossed after 87.81 seconds
# Time 352.31: Vehicle 172 from Bakeri1 crossed after 77.53 seconds
# Time 353.94: Vehicle 144 from Bakeri1 crossed after 78.78 seconds
# Time 354.09: Vehicle 173 from Bakeri1 crossed after 71.43 seconds
# Time 355.44: Vehicle 190 from Besat2 crossed after 38.50 seconds
# Time 356.21: Vehicle 158 from Bakeri1 crossed after 64.44 seconds
# Time 356.45: Vehicle 180 from Bakeri1 crossed after 55.21 seconds
# Time 356.96: Vehicle 149 from Bakeri1 crossed after 55.62 seconds
# Time 357.71: Vehicle 145 from Bakeri1 crossed after 54.77 seconds
# Time 360.14: Vehicle 131 from Bakeri1 crossed after 41.80 seconds
# Time 369.35: Vehicle 184 from Bakeri1 crossed after 46.77 seconds
# Time 374.34: Vehicle 189 from Bakeri1 crossed after 44.45 seconds
# Time 375.00: Light turned GREEN for Bakeri2
# Time 375.86: Vehicle 177 from Bakeri2 crossed after 99.61 seconds
# Time 379.24: Vehicle 186 from Bakeri2 crossed after 86.33 seconds
# Time 379.80: Vehicle 201 from Bakeri2 crossed after 83.20 seconds
# Time 381.23: Vehicle 199 from Bakeri2 crossed after 67.87 seconds
# Time 381.24: Vehicle 196 from Bakeri2 crossed after 62.19 seconds
# Time 382.18: Vehicle 191 from Bakeri2 crossed after 56.54 seconds
# Time 382.65: Vehicle 187 from Bakeri2 crossed after 56.49 seconds
# Time 383.11: Vehicle 168 from Bakeri2 crossed after 50.22 seconds
# Time 383.39: Vehicle 148 from Bakeri2 crossed after 40.50 seconds
# Time 383.55: Vehicle 167 from Bakeri2 crossed after 38.25 seconds
# Time 383.68: Vehicle 181 from Bakeri2 crossed after 36.22 seconds
# Time 400.00: Light turned GREEN for Besat1
# Time 403.04: Vehicle 170 from Besat1 crossed after 138.58 seconds
# Time 404.58: Vehicle 206 from Besat1 crossed after 137.56 seconds
# Time 416.07: Vehicle 176 from Besat1 crossed after 148.71 seconds
# Time 417.53: Vehicle 188 from Besat1 crossed after 137.33 seconds
# Time 417.70: Vehicle 160 from Besat1 crossed after 136.89 seconds
# Time 417.75: Vehicle 197 from Besat1 crossed after 134.20 seconds
# Time 417.76: Vehicle 205 from Besat1 crossed after 129.88 seconds
# Time 417.78: Vehicle 200 from Besat1 crossed after 118.35 seconds
# Time 417.92: Vehicle 150 from Besat1 crossed after 118.39 seconds
# Time 417.99: Vehicle 161 from Besat1 crossed after 117.14 seconds
# Time 418.04: Vehicle 171 from Besat1 crossed after 112.70 seconds
# Time 418.06: Vehicle 164 from Besat1 crossed after 98.27 seconds
# Time 418.15: Vehicle 151 from Besat1 crossed after 98.27 seconds
# Time 418.17: Vehicle 198 from Besat1 crossed after 89.00 seconds
# Time 418.17: Vehicle 152 from Besat1 crossed after 74.47 seconds
# Time 418.25: Vehicle 169 from Besat1 crossed after 73.80 seconds
# Time 418.25: Vehicle 183 from Besat1 crossed after 71.88 seconds
# Time 418.41: Vehicle 163 from Besat1 crossed after 67.74 seconds
# Time 418.47: Vehicle 182 from Besat1 crossed after 67.70 seconds
# Time 424.50: Vehicle 208 from Besat1 crossed after 68.45 seconds
# Time 428.15: Vehicle 213 from Besat1 crossed after 69.51 seconds
# Time 429.77: Vehicle 209 from Besat1 crossed after 63.02 seconds
# Time 430.00: Light turned GREEN for Besat2
# Time 434.99: Vehicle 218 from Besat2 crossed after 117.42 seconds
# Time 436.56: Vehicle 221 from Besat2 crossed after 112.37 seconds
# Time 437.34: Vehicle 185 from Besat2 crossed after 106.29 seconds
# Time 438.36: Vehicle 216 from Besat2 crossed after 102.54 seconds
# Time 438.58: Vehicle 235 from Besat2 crossed after 102.66 seconds
# Time 438.83: Vehicle 178 from Besat2 crossed after 83.04 seconds
# Time 438.84: Vehicle 211 from Besat2 crossed after 75.24 seconds
# Time 438.97: Vehicle 236 from Besat2 crossed after 74.61 seconds
# Time 439.28: Vehicle 212 from Besat2 crossed after 66.14 seconds
# Time 439.46: Vehicle 179 from Besat2 crossed after 63.82 seconds
# Time 440.58: Vehicle 192 from Besat2 crossed after 61.53 seconds
# Time 442.16: Vehicle 233 from Besat2 crossed after 52.45 seconds
# Time 443.19: Vehicle 193 from Besat2 crossed after 49.34 seconds
# Time 443.35: Vehicle 214 from Besat1 crossed after 76.50 seconds
# Time 446.38: Vehicle 207 from Besat2 crossed after 46.41 seconds
# Time 446.66: Vehicle 231 from Besat2 crossed after 45.22 seconds
# Time 460.00: Light turned GREEN for Bakeri1
# Time 460.82: Vehicle 246 from Besat2 crossed after 54.93 seconds
# Time 463.20: Vehicle 234 from Bakeri1 crossed after 124.89 seconds
# Time 463.35: Vehicle 264 from Besat2 crossed after 47.58 seconds
# Time 464.44: Vehicle 194 from Bakeri1 crossed after 125.49 seconds
# Time 464.75: Vehicle 195 from Bakeri1 crossed after 116.32 seconds
# Time 465.15: Vehicle 238 from Bakeri1 crossed after 116.62 seconds
# Time 465.17: Vehicle 210 from Bakeri1 crossed after 116.48 seconds
# Time 466.58: Vehicle 222 from Bakeri1 crossed after 103.13 seconds
# Time 466.92: Vehicle 240 from Besat2 crossed after 47.13 seconds
# Time 467.49: Vehicle 241 from Bakeri1 crossed after 95.22 seconds
# Time 467.68: Vehicle 203 from Bakeri1 crossed after 89.08 seconds
# Time 468.43: Vehicle 247 from Bakeri1 crossed after 89.25 seconds
# Time 469.00: Vehicle 215 from Bakeri1 crossed after 87.57 seconds
# Time 469.31: Vehicle 227 from Bakeri1 crossed after 85.75 seconds
# Time 469.90: Vehicle 202 from Bakeri1 crossed after 74.13 seconds
# Time 470.32: Vehicle 220 from Bakeri1 crossed after 65.09 seconds
# Time 470.34: Vehicle 237 from Bakeri1 crossed after 64.97 seconds
# Time 470.51: Vehicle 204 from Bakeri1 crossed after 63.47 seconds
# Time 472.50: Vehicle 225 from Bakeri1 crossed after 53.19 seconds
# Time 473.36: Vehicle 251 from Bakeri1 crossed after 49.02 seconds
# Time 475.14: Vehicle 249 from Bakeri1 crossed after 49.26 seconds
# Time 480.28: Vehicle 248 from Besat2 crossed after 50.55 seconds
# Time 485.51: Vehicle 255 from Bakeri1 crossed after 55.45 seconds
# Time 487.21: Vehicle 254 from Bakeri1 crossed after 55.52 seconds
# Time 490.00: Light turned GREEN for Bakeri2
# Time 492.23: Vehicle 274 from Bakeri2 crossed after 112.73 seconds
# Time 494.73: Vehicle 250 from Bakeri2 crossed after 88.88 seconds
# Time 495.99: Vehicle 260 from Bakeri2 crossed after 88.31 seconds
# Time 496.33: Vehicle 257 from Bakeri2 crossed after 88.11 seconds
# Time 496.52: Vehicle 223 from Bakeri2 crossed after 84.22 seconds
# Time 496.76: Vehicle 242 from Bakeri2 crossed after 71.92 seconds
# Time 497.08: Vehicle 275 from Bakeri2 crossed after 60.99 seconds
# Time 497.65: Vehicle 244 from Bakeri2 crossed after 51.97 seconds
# Time 498.34: Vehicle 239 from Bakeri2 crossed after 29.89 seconds
# Average vehicle cycle time per street:
# Bakeri1: 79.48 seconds
# Bakeri2: 64.35 seconds
# Besat1: 95.79 seconds
# Besat2: 75.29 seconds
